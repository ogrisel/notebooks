# %%
# %pylab inline
import pylab as pl
from sklearn.datasets import fetch_olivetti_faces
from sklearn.cross_validation import train_test_split
from sklearn.utils import shuffle
pl.gray()
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
olivetti = fetch_olivetti_faces()
faces = olivetti.images
faces_train, faces_test, target_train, target_test = train_test_split(
    olivetti.images, olivetti.target)

# %%
pl.imshow(faces_train[0])

# %%
from sklearn.feature_extraction.image import PatchExtractor

# %%
pe = PatchExtractor((8, 8), random_state=42)
patches = pe.transform(faces_train)

# %%
patches.shape
# Out:
# (974700, 8, 8)

# %%
def plot_patches(patches, n_rows=8, n_cols=12):
    pl.figure(figsize=(1.2 * n_cols, 1.2 * n_rows))
    for i in range(n_rows):
        for j in range(n_cols):
            idx = i * n_cols + j
            if idx < len(patches):
                pl.subplot(n_rows, n_cols, i * n_cols + j)
                pl.imshow(patches[idx].reshape(8, 8), interpolation='nearest')
                pl.axis('off')

# %%
plot_patches(patches)

# %%
patches = shuffle(patches)[:10000]

# %%
plot_patches(patches)

# %%
from sklearn.cluster import MiniBatchKMeans

# %%
km = MiniBatchKMeans(n_clusters=1000, batch_size=500, verbose=0, n_init=1, random_state=42)
% time km.fit(patches.reshape(-1, 64))
# Out:
# CPU times: user 4.9 s, sys: 184 ms, total: 5.08 s
# Wall time: 4.78 s
# MiniBatchKMeans(batch_size=500, compute_labels=True, init='k-means++',
#         init_size=None, k=None, max_iter=100, max_no_improvement=10,
#         n_clusters=1000, n_init=1, random_state=42,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)

# %%
centroids = km.cluster_centers_
centroids.shape
# Out:
# (1000, 64)

# %%
plot_patches(centroids)

# %%
km_10 = MiniBatchKMeans(n_clusters=10, batch_size=500, verbose=0, n_init=1, random_state=42)
% time km_10.fit(patches.reshape(-1, 64))
# Out:
# CPU times: user 167 ms, sys: 5.97 ms, total: 173 ms
# Wall time: 168 ms
# MiniBatchKMeans(batch_size=500, compute_labels=True, init='k-means++',
#         init_size=None, k=None, max_iter=100, max_no_improvement=10,
#         n_clusters=10, n_init=1, random_state=42, reassignment_ratio=0.01,
#         tol=0.0, verbose=0)

# %%
plot_patches(km_10.cluster_centers_)

# %%
projected_patches = np.dot(patches.reshape(-1, 8 * 8), centroids.T)
projected_patches.shape
# Out:
# (10000, 1000)

# %%
thresholds = np.median(projected_patches, axis=0)
thresholds.shape
# Out:
# (1000,)

# %%
thresholded_patches = projected_patches - thresholds
thresholded_patches[thresholded_patches < 0] = 0.0

# %%
np.mean(thresholded_patches > 0)
# Out:
# 0.5

# %%
# TODO
