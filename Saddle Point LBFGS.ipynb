# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x, y):
    return x ** 3 - 3 * x * y ** 2

def df(x, y):
    return np.array([
        3 * x ** 2 - 3 * y ** 2,
        - 6 * x * y,
    ])

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

X, Y = np.meshgrid(x, y)
plt.figure(figsize=(10, 10))
plt.contour(X, Y, f(X, Y), 10, cmap=plt.cm.RdBu)
plt.contourf(X, Y, f(X, Y), 100, cmap=plt.cm.RdBu);

# %%
def eval_params(x):
    return f(x[0], x[1]), df(x[0], x[1])

eval_params([0., 0.])
# Out:
# (0.0, array([ 0., -0.]))

# %%
from scipy.optimize import fmin_l_bfgs_b

fmin_l_bfgs_b(eval_params, np.array([1, 0.0001]), disp=10)
# Out:
# (array([  1.99999999e-08,   2.99999998e-04]),
#  -5.3999998871816589e-15,
#  {'task': b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL',
#   'grad': array([ -2.69999995e-07,  -3.59999995e-11]),
#   'nit': 1,
#   'funcalls': 2,
#   'warnflag': 0})

# %%
fmin_l_bfgs_b(eval_params, np.array([-.002, .003]), disp=10)
# Out:
# (array([  5.22692538e+51,  -6.24607177e+53]),
#  nan,
#  {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH',
#   'grad': array([ -1.17032042e+108,   1.95886506e+106]),
#   'nit': 3,
#   'funcalls': 68,
#   'warnflag': 2})

# %%
x_small = np.linspace(-.1, .1, 10)
y_small = np.linspace(-.1, .1, 10)

X_small, Y_small = np.meshgrid(x_small, y_small)

rng = np.random.RandomState(42)
pairs = [rng.uniform(-.5, .5, size=2) for i in range(500)]

attracted = np.array([
    (x, y) for x, y in pairs
    if fmin_l_bfgs_b(eval_params, np.array([x, y]))[2]['task'].startswith(b'CONVERGENCE: ')
])
attracted
# Out:
# array([[ 0.10111501,  0.20807258],
#        [-0.19538623, -0.40232789],
#        [ 0.43949894,  0.39482735],
#        [-0.11132271, -0.22865097],
#        [ 0.38721274, -0.02778507],
#        [-0.47458087, -0.39210857],
#        [-0.18199653, -0.38994808],
#        [ 0.46244729, -0.2482177 ],
#        [ 0.01209306, -0.27350422],
#        [ 0.1496329 ,  0.34922341],
#        [ 0.1454723 , -0.32288932],
#        [ 0.41486439, -0.1298413 ],
#        [-0.07181585,  0.46665482],
#        [-0.33050725,  0.05680126],
#        [ 0.11500723,  0.49005385],
#        [-0.03440198,  0.04264463],
#        [-0.44831828,  0.03135463],
#        [ 0.05435405,  0.11172075],
#        [-0.02582617, -0.40216584],
#        [-0.47348869,  0.08577558],
#        [-0.399222  , -0.48177817],
#        [ 0.34487531, -0.47672806],
#        [-0.1799504 ,  0.39552323],
#        [ 0.13183721, -0.05155448],
#        [-0.44244124,  0.04952888],
#        [-0.38247375,  0.1492103 ],
#        [-0.04545894,  0.12755808],
#        [-0.12353663,  0.31055333],
#        [ 0.11812824, -0.14183728],
#        [ 0.20407977, -0.28703584],
#        [-0.10775595, -0.06252508],
#        [-0.10345722,  0.1220867 ],
#        [ 0.36236371,  0.44952062],
#        [-0.00738191, -0.17124839],
#        [ 0.39678841, -0.02603836],
#        [-0.33106494, -0.22140966],
#        [ 0.37357862,  0.4208724 ],
#        [ 0.11825477, -0.13108636],
#        [ 0.01167744,  0.03211349],
#        [-0.41307971,  0.03710654],
#        [-0.31343298, -0.21490483],
#        [ 0.07447311,  0.34182878],
#        [-0.2677873 ,  0.39957457],
#        [-0.36072793,  0.29402519],
#        [ 0.39389258,  0.28859721],
#        [-0.46646757,  0.06988968],
#        [-0.15791825,  0.3212573 ],
#        [ 0.29729537, -0.35008257],
#        [ 0.00588868,  0.11145424],
#        [-0.37533732,  0.42084188],
#        [ 0.23750125, -0.04778206],
#        [-0.27539518, -0.04756048],
#        [ 0.27552762, -0.04671117],
#        [ 0.26360579, -0.35988682],
#        [-0.33371663,  0.23803362],
#        [ 0.21904591, -0.20287828],
#        [ 0.06640464, -0.0239496 ],
#        [ 0.16367117,  0.43682974],
#        [-0.00363375,  0.09684285]])

# %%
x = np.linspace(-.5, .5, 100)
y = np.linspace(-.5, .5, 100)

X, Y = np.meshgrid(x, y)
plt.figure(figsize=(10, 10))
plt.contour(X, Y, f(X, Y), 10, cmap=plt.cm.RdBu)
plt.contourf(X, Y, f(X, Y), 100, cmap=plt.cm.RdBu)
plt.scatter(attracted[:, 0], attracted[:, 1]);
